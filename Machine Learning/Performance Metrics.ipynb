# %% [markdown]
# ###### Accuracy for Classification - 3rd October

# %% [markdown]
# ###### Accuracy

# %%
from IPython.display import Image

# %%
Image('Accuracy.png')

# %% [markdown]
# ###### Confusion Matrix

# %%
Image('confusion matrix.jpg')

# %%
Image("class metrics.jpeg")

# %% [markdown]
# ###### ROC and AUC

# %%
# ROC uses the sorting of probability values
# no metrics use probability values
# ROC tells us what threshold we need
# Auc helps us to decide which ML model to productionize
# ROC helps us to find the threshold
