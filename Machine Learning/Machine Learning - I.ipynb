# %% [markdown]
# # 29th August Machine Learning Intro

# %%
# Artificial Intelligence --> Develop some application that can perform with any human interaction 
# Eg --> Self Driving cars, Netflix Recommendation

# Machine Learning --> ML is a suset of AI. ML provides stats tools to analyse the data, visualize the data, 
# perform predictions and forecasting.

# Deep Learning --> DL is a subset of ML. 
# Can we make Machine Learn as we human beings learn.
# The main focus is to mimic human brain
# Scientists came up with neural networks

# Data science --> DS is combined with AI,ML and DL
# A Data scientist will be performing any tasks given in these regions.

# AI vs ML vs DL vs DS

# Computer Vision --> Video and images
# NLP --> Whenever Input is text data, we use NLP to convert to numerical format/vectors so it can be a part of ML and DL 

# Our final goal is to create AI based application

# %%
from IPython.display import Image

# %%
Image('DATA SCIENCE.png')

# %%
# ML
    # Supervised Learning --> Output is known 
        # Classification --> Output has categories
        # Regression --> Output is continous
    # Unsupervised Learning --> Output is unknown (Clustering)
    # Semi-Supervised Learning --> Outputs are known and unknown (Reinforcement Learning)
        # Initially we will be finding labelled data and then not found

# DL
    # The same Supervised, unsupervised and reinforcement learning will happen in DL.

# %% [markdown]
# ###### Life cycle of a machine learning project
