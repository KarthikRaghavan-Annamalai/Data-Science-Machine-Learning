# %% [markdown]
# # 25th July Review Scrapper Project

# %%
# Step 1 - Setup for the project

# %% [raw]
# conda activate reviewFlask
# conda info --envs
# pip install -r requirements.txt

# %%
conda info --envs
# Out:
# # conda environments:
# #
# base                  *  C:\ProgramData\Anaconda3
# Deployment               C:\ProgramData\Anaconda3\envs\Deployment
# Flask_Demo               C:\ProgramData\Anaconda3\envs\Flask_Demo
# Review_Scrapper          C:\ProgramData\Anaconda3\envs\Review_Scrapper
# reviewFlask              C:\ProgramData\Anaconda3\envs\reviewFlask
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from flask import Flask, render_template, request,jsonify
from flask_cors import CORS,cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
searchString = request.form['content'].replace(" ","")
flipkart_url = "https://www.flipkart.com/search?q=" + searchString
uClient = uReq(flipkart_url)
flipkartPage = uClient.read()
uClient.close()
flipkart_html = bs(flipkartPage, "html.parser")
bigboxes = flipkart_html.findAll("div", {"class": "_1AtVbE col-12-12"})
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_22440/1690660167.py in <module>
# ----> 1 searchString = request.form['content'].replace(" ","")
#       2 flipkart_url = "https://www.flipkart.com/search?q=" + searchString
#       3 uClient = uReq(flipkart_url)
#       4 flipkartPage = uClient.read()
#       5 uClient.close()
#
# C:\ProgramData\Anaconda3\lib\site-packages\werkzeug\local.py in __get__(self, instance, owner)
#     276
#     277         try:
# --> 278             obj = instance._get_current_object()
#     279         except RuntimeError:
#     280             if self.fallback is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\werkzeug\local.py in _get_current_object(self)
#     405         """
#     406         if not hasattr(self.__local, "__release_local__"):  # type: ignore
# ...

# %%
uReq("https://www.flipkart.com/search?q=Smartwatch")

# %%
uReq("https://www.flipkart.com/search?q=Smartwatch").read()
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app_modules.chunk.94b5e7.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.493c50.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/a
# ...

# %%
uReq("https://www.flipkart.com/search?q=Smartwatch").close()

# %%
bs(uReq("https://www.flipkart.com/search?q=Smartwatch").read(),"html.parser")
# Out:
# <!DOCTYPE html>
# ...

# %%
bs(uReq("https://www.flipkart.com/search?q=Smartwatch").read(),"html.parser").findAll("div", {"class": "_1AtVbE col-12-12"})
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/wearable-smart-devices/pr?sid=ajy&amp;q=Smartwatch&amp;otracker=categorytree" title="Wearable Smart Devices">Wearable Smart Devices</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/wearable-smart-devi
# ...

# %%
bs(uReq("https://www.flipkart.com/search?q=Smartwatch").read(),"html.parser").findAll("div", {"class": "_1AtVbE col-12-12"})[0]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/wearable-smart-devices/pr?sid=ajy&amp;q=Smartwatch&amp;otracker=categorytree" title="Wearable Smart Devices">Wearable Smart Devices</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/wearable-smart-devic
# ...

# %%
bs(uReq("https://www.flipkart.com/search?q=Smartwatch").read(),"html.parser").findAll("div", {"class": "_1AtVbE col-12-12"})[1]
# Out:
# <div class="_1AtVbE col-12-12"><a class="_1nY1tt" href="/buying-guide/smart-watches?sid=ajy,buh&amp;otracker=bg_from_browse_lhs" title="Buying Guide"><div><span>Need help?</span></div><div class="_1mVNvF"><span>Help me decide</span><svg class="ViewtL" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg"><path class="_2Zt1Py" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></div><img alt="Buying Guide" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/buying-guide-illustration_4dd325.png"/></a></div>

# %%
bs(uReq("https://www.flipkart.com/search?q=Smartwatch").read(),"html.parser").findAll("div", {"class": "_1AtVbE col-12-12"})[2]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_13oc-S"><div data-id="SMWGEH7VGYMGCP3V" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/noise-colorfit-icon-2-1-8-display-bluetooth-calling-ai-voice-assistance-smartwatch/p/itmfa97e2fcabed9?pid=SMWGEH7VGYMGCP3V&amp;lid=LSTSMWGEH7VGYMGCP3VWUYKLZ&amp;marketplace=FLIPKART&amp;q=Smartwatch&amp;store=ajy%2Fbuh&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=28ed3717-504e-4dc1-aa31-e930c222687c.SMWGEH7VGYMGCP3V.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=vf5b7xbm800000001658151556383&amp;qH=cd12463a571bb3fd" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Noise ColorFit Icon 2 1.8 Display, Bluetooth Calling, AI Voice Assistance Smartwatch" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/312/312/l5ld8y80/smartwatch/r/q/t/-original-imagg8dksgct9hxg.jpeg?q=70"/></div></div><div class="_3G6awp"><span class
# ...

# %%
bs(uReq("https://www.flipkart.com/search?q=Smartwatch").read(),"html.parser").findAll("div", {"class": "_1AtVbE col-12-12"})[3]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_13oc-S"><div data-id="SMWGEH7V3NRGVPQ9" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/noise-colorfit-icon-2-1-8-display-bluetooth-calling-ai-voice-assistance-smartwatch/p/itm339ed82cec89e?pid=SMWGEH7V3NRGVPQ9&amp;lid=LSTSMWGEH7V3NRGVPQ9SWKH5T&amp;marketplace=FLIPKART&amp;q=Smartwatch&amp;store=ajy%2Fbuh&amp;srno=s_1_2&amp;otracker=search&amp;fm=organic&amp;iid=40e68db8-bede-4848-a503-8abcc4eab102.SMWGEH7V3NRGVPQ9.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=5881hnfq3k0000001658151562808&amp;qH=cd12463a571bb3fd" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Noise ColorFit Icon 2 1.8 Display, Bluetooth Calling, AI Voice Assistance Smartwatch" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/312/312/l5ld8y80/smartwatch/f/k/q/-original-imagg8d9hbkhfffg.jpeg?q=70"/></div></div><div class="_3G6awp"><span class
# ...

# %%
bs(uReq("https://www.flipkart.com/search?q=Smartwatch").read(),"html.parser").findAll("div", {"class": "_1AtVbE col-12-12"})[4]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_13oc-S"><div data-id="SMWG6RB5FX7RXWZ8" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/noise-colorfit-qube-spo2-smartwatch/p/itm2d9dc41a02202?pid=SMWG6RB5FX7RXWZ8&amp;lid=LSTSMWG6RB5FX7RXWZ8MROVKI&amp;marketplace=FLIPKART&amp;q=Smartwatch&amp;store=ajy%2Fbuh&amp;srno=s_1_3&amp;otracker=search&amp;fm=organic&amp;iid=2d9061b5-63a4-4b04-b660-30d82f04a2ae.SMWG6RB5FX7RXWZ8.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=5mtvp5exwg0000001658151568815&amp;qH=cd12463a571bb3fd" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Noise ColorFit Qube SpO2 Smartwatch" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/312/312/ku1k4280/smartwatch/t/i/a/android-ios-wrb-sw-colorfitqubeoxy-std-blk-blk-noise-no-original-imag79y4ar4hjbgb.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><lab
# ...

# %%
"https://www.flipkart.com" + bs(uReq("https://www.flipkart.com/search?q=Smartwatch").read(),"html.parser").findAll("div", {"class": "_1AtVbE col-12-12"})[4].div.div.div.a['href']
# Out:
# 'https://www.flipkart.com/noise-colorfit-qube-spo2-smartwatch/p/itm2d9dc41a02202?pid=SMWG6RB5FX7RXWZ8&lid=LSTSMWG6RB5FX7RXWZ8MROVKI&marketplace=FLIPKART&q=Smartwatch&store=ajy%2Fbuh&srno=s_1_3&otracker=search&fm=organic&iid=1291440c-fd2f-4220-a5ff-07486757fb09.SMWG6RB5FX7RXWZ8.SEARCH&ppt=None&ppn=None&ssid=7kwcpxggtc0000001658151638012&qH=cd12463a571bb3fd'

# %% [markdown]
# # 31st July Review Scrapper Project Discussion and Heroku Deployment

# %%
# Flask-Cors another region deployment remediation

# %%
# Flask-we are trying to create a flask app so that we can bind our functions with certain set of URL's

# %% [raw]
# $ git init
# $ heroku git:remote -a flipkart-scraping-deployment
# $ git add .
# $ git commit -am "make it better"
# $ git push heroku master
