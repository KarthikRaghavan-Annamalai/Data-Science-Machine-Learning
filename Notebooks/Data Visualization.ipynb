# %% [markdown]
# # Matplotlib and Seaborn

# %%
# Data Visualization

# %%
# Graph is also a good way to visualize the data for trends

# %%
import matplotlib as mlt
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %matplotlib inline #Helps in getting the plot in Jupyter notebook

# %%
df = pd.DataFrame(np.random.randn(1000),index = pd.date_range('2019-06-07',periods=1000),columns=['value'])

# %%
df
# Out:
#                value
# 2019-06-07  0.719432
# 2019-06-08 -1.808732
# 2019-06-09 -0.337802
# 2019-06-10  0.103810
# 2019-06-11 -0.157192
# ...              ...
# 2022-02-26  0.097638
# 2022-02-27  0.502792
# 2022-02-28 -0.362559
# 2022-03-01 -0.213405
# 2022-03-02 -1.508267
#
# [1000 rows x 1 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.value.cumsum().plot()
# Out:
# <AxesSubplot:>

# %%
# In a graph, we have x and y axis, we are using dates on the x axis and values are on the y axis

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.plot()
plt.show()

# %%
species = iris.species

# %%
iris.drop('species',axis = 1,inplace=True)

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
iris.iloc[[0]].plot.bar()
# Out:
# <AxesSubplot:>

# %%
iris.iloc[0].plot.bar()
# Out:
# <AxesSubplot:>

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.survived.value_counts().plot.pie(autopct='%1.2f%%')
# Out:
# <AxesSubplot:ylabel='survived'>

# %%
titanic.pclass.value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='pclass'>

# %%
titanic.pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %%
titanic.pclass.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# <>-------------------------------------------------------------------------------------------------------------------------<>

# %%
df = pd.DataFrame(np.random.randn(10,4),columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.706604  0.229415  0.485512  1.707018
# 1  0.599375  0.628293  0.479884  1.132366
# 2 -1.180198 -0.646453 -0.608012  1.207906
# 3 -1.414994  0.542266  0.935201 -0.497728
# 4  1.448494  1.894669  0.048958  0.559562
# 5 -1.238873  1.592391  0.142706 -1.119514
# 6 -0.870214 -0.053372 -0.924139  0.904282
# 7 -0.362825 -0.075763 -0.240421  0.771524
# 8 -0.605754  0.252355 -0.429354 -0.301393
# 9 -0.123133  0.898810  0.997845  0.428916

# %%
df.plot.line()
# Out:
# <AxesSubplot:>

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.barh()
# Out:
# <AxesSubplot:>

# %%
iris.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.sepal_length.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
iris.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot.hist(stacked = True,bins = 100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot.hist(stacked = True,bins = 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot.hist(stacked = True,bins = 50,orientation = 'horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
iris.hist(color = '#76a5af',alpha = 0.5,figsize=(10,7))
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
# hexacode for color

# https://www.color-hex.com/

# %%
iris.plot.scatter(x = 'sepal_length',y = 'sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
iris.plot.scatter(x = 'sepal_length',y = 'petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
iris.plot.scatter(x = 'sepal_length',y = 'petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
iris.plot.scatter(x = 'sepal_length',y = 'sepal_width',c = 'sepal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
iris.plot.scatter(x = 'sepal_length',y = 'sepal_width',c = 'sepal_length',s = 100)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
iris.plot.hexbin(x = 'sepal_length',y = 'sepal_width',gridsize= 15,figsize=(10,7),C = 'sepal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
iris.iloc[0][0:4].plot.pie()
# Out:
# <AxesSubplot:ylabel='0'>

# %%
iris.head(3).iloc[:,0:4].T.plot.pie(subplots=True,figsize=(20,20),autopct='%1.2f%%')
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
iris.drop('species',axis=1,inplace=True)

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
pd.plotting.scatter_matrix(iris,figsize=(15,10),color = 'r',s = 100,diagonal='kde') # another method for pairplot
plt.show()

# %%
iris.sepal_length.plot(style = 'r--',figsize=(15,10))
# Out:
# <AxesSubplot:>

# %%
iris.sepal_length.plot(style = 'r--',figsize=(10,7),label = 'sepal_length',legend = True)
# Out:
# <AxesSubplot:>
