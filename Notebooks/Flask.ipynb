# %% [markdown]
# # 12th June Flask

# %%
# Pycharm (Community Version) and Postman download and install

# API - Request and Response 
# establish connection between 2 different interfaces with different languages or frameworks
# Application Programming Interface
# API helps us to communicate between homogenous or heterogenous system
# Allows us to perform operations in different languages
# Eg Google Pay, Jupyter Notebook

# %%
# Pycharm - IDE
# We do odular coding in Oycharm and not in jupyter notebook

# %%
from IPython import display

# %%
display.Image('API.png')

# %%
 # Download flask_demo

# %%
# libraries / packages for API creation for Python

# django
# flask
# clean

# %%
# Methods for sending data

# GET - the URL will show the search results while sending data
# POST - the URL will not show the search results while sending data

# get - sending data over url
# post - sending data over body

# %%
pip list
# Out:
# Package                            Version
# ---------------------------------- --------------------
# alabaster                          0.7.12
# anaconda-client                    1.9.0
# anaconda-navigator                 2.1.2
# anaconda-project                   0.10.1
# anyio                              2.2.0
# appdirs                            1.4.4
# apriori                            1.0.0
# apyori                             1.1.2Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -qdm (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lask (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lask (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\programdata\anaconda3\lib\site-packages)
# ...

# %%
from flask import Flask # importing Flask (API)
# It is a micro framework
#

# %%
# json is like a dictionary- key value pair format
# request is nothing but a class

# %%
def math_operation_via_postman():
    operation= 'add'
    num1= 8
    num2 = 6
    if (operation=='add'):
        r=num1+num2
        result= 'the sum of '+str(num1)+' and '+str(num2) +' is '+str(r)
    if (operation == 'subtract'):
        r = num1 - num2
        result = 'the difference of ' + str(num1) + ' and ' + str(num2) + ' is ' + str(r)
    if (operation == 'multiply'):
        r = num1 * num2
        result = 'the product of ' + str(num1) + ' and ' + str(num2) + ' is ' + str(r)
    if (operation == 'divide'):
        r = num1 / num2
        result = 'the quotient when ' + str(num1) + ' is divided by ' + str(num2) + ' is ' + str(r)
    return result

# %%
math_operation_via_postman()
# Out:
# 'the sum of 8 and 6 is 14'

# %%
# app = Flask(__name__) --> we can give any name as app
# __name__ - default constructor

# %%
#if __name__ == '__main__':
#    app.run()

# we have to create a main file in python

# %%
# http:127.0.0.1:5000 

# 127.0.0.1 is the default local host from system
# 5000 default port postman occupies

# %%
# Postman is a tool to test API

# %%
# http://127.0.0.1:5000/demo_run --> This is called as API(our own)
